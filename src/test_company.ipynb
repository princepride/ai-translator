# %%
company = [
    "中矿澳大利亚有限公司",
    "中国云铜（澳大利亚）投资开发有限公司",
    "国家电网公司驻澳大利亚办事处",
    "河北矿业（澳大利亚）控股有限责任公司",
    "云南锡业集团澳大利亚TDK资源有限公司",
    "沈阳远大铝业工程有限公司",
    "金风澳洲有限公司",
    "北京京能清洁能源电力股份有限公司（澳洲项目公司）",
    "中节能风电（澳大利亚）控股有限公司",
    "洛阳钼业澳洲公司",
    "阿林塔能源",
    "中远海运(澳洲)有限公司",
    "中车澳大利亚有限公司",
    "神华澳大利亚控股有限公司",
    "中石化国际事业澳大利亚有限公司",
    "天合光能",
    "澳中财富集团",
    "华光资源有限公司",
    "宙斯资源有限公司",
    "三一澳大利亚",
    "铭瑞锆业有限公司",
    "永刚集团",
    "澳洲五矿有限公司",
    "中信资源澳大利亚有限公司",
    "五矿资源有限公司",
    "中国电建澳大利亚发展有限公司",
    "神华清洁能源控股公司",
    "中远海运散运（澳洲）有限公司",
    "中车时代电气澳洲有限责任公司",
    "中联重科澳新公司",
    "澳大利亚中车长客轨道交通装备有限公司",
    "中车资阳（澳大利亚）有限公司",
    "Alinta Energy Pty Ltd",
    "三一澳大利亚有限公司",
    "五矿劲飞有限公司",
    "中石油技术开发公司澳大利亚子公司",
    "神火国际集团有限公司",
    "信发澳洲有限公司",
    "广东能源集团超康投资",
    "中海油",
    "中煤资源有限公司",
    "皖北煤电",
    "澳陕矿业",
    "中拓资源有限公司",
    "Huaxin Energy (Aust) Pty Ltd",
    "爱康能源澳大利亚有限公司",
    "PanAust Limited",
    "中国石油国际事业（澳大利亚）有限公司",
    "澳大利亚坤谦国际能源有限公司",
    "中石化国际事业澳大利亚公司",
    "中国华能澳洲代表处",
    "东方日升新能源（澳大利亚）有限公司",
    "中石油国际投资有限公司(澳大利亚）公司",
    "中国石化澳大利亚公司",
    "中石油工程建设公司",
    "金鑫设备有限责任公司",
    "中钢澳洲中西矿业有限公司",
    "宝钢澳大利亚矿业有限公司",
    "紫金矿业诺顿金田有限公司",
    "中海油澳大利亚国际控股有限公司",
    "中冶西澳矿业有限公司",
    "鞍钢澳大利亚投资有限公司",
    "宝钢澳大利亚有限公司",
    "宝武资源澳大利亚有限公司",
    "中国广东核电澳大利亚有限公司",
    "金川金田镍业有限公司",
    "马钢澳大利亚有限公司",
    "河北钢铁澳大利亚有限公司",
    "沙钢澳大利亚有限公司",
    "中钢澳大利亚矿业有限公司",
    "丰立澳大利亚有限公司",
    "中信泰富矿业管理有限公司",
    "济南高新控股集团明加尔金源有限公司",
    "中金岭南有色金属股份有限公司",
    "重钢澳大利亚有限公司",
    "宁夏天元锰业澳大利亚联合矿业有限公司",
    "山东黄金国际集团",
    "河南信阳钢铁澳大利亚公司",
    "金伯利铁矿有限公司",
    "科思米克资源控股有限公司",
    "中国国储能源澳大利亚有限公司",
    "广东东方锆业科技股份公司",
    "东方日升澳大利亚公司",
    "中石油国际投资（澳大利亚）公司西澳项目",
    "天齐锂业澳洲公司",
    "中远海运澳洲船务有限公司",
    "中国船级社澳大利亚办事处",
    "中国外运澳大利亚有限公司",
    "中石化润滑油有限公司",
    "凯瑞工程建设集团",
    "中车长江（澳大利亚）车辆服务有限公司",
    "湖南长沙黑金刚实业澳大利亚有限公司",
    "安徽三方新材料科技澳大利亚公司",
    "百年宝通澳大利亚通输送系统服务公司",
    "华特磁电澳大利亚公司",
    "青岛泰凯英轮胎澳大利亚有限公司",
    "南昌矿山机械澳大利亚公司",
    "江阴怡源设备安装有限公司",
    "三一集团澳大利亚公司",
    "中检集团澳大利亚公司",
    "大地(澳大利亚)工程有限公司",
    "广州普朗思电气科技有限公司",
    "疆宇科技有限公司",
    "天合光能股份有限公司",
    "阿里云",
    "中联重科澳新子公司",
    "北京易控智驾澳大利亚分公司",
]

# %%
from openai import OpenAI
client = OpenAI()

from dotenv import load_dotenv
load_dotenv()

def search_company(company_name):
    prompt = """
    {
        "客户": "兖煤澳大利亚有限公司",
        "英文公司名": "YANCOAL AUSTRALIA LIMITED",
        "客户信息": "澳洲最大的煤炭出口商之一，生产优质的动力煤和焦煤。2004年由兖矿集团控股整合，现总部设于悉尼和纽卡斯尔附近的猎人谷。旗下主要矿区包括：36座煤矿，主要位于新南威尔士州中北部和昆士兰州，如: Eltanoballen、Mount Thorley Warkworth、Hunter Valley Operations等；客户目前通过新加坡子公司销售约62.26%，中国区占比约15.89%。https://www.yancoal.com.au/",
        "营收": "68.6亿", 
        "净利润":"12.16亿",
        "人员规模": "3,000",
        "联系人": "CFO: 苏宁 (Kevin)\nhttps://www.linkedin.com/in/kevin-ning-su-fcpa-55397651/",
        "是否用友客户": "其他厂商", 
        "客户使用系统": "SAP",
        "潜在商机": "" 
    }
    请参考上面的格式填写"""+ '"' + company_name+ '"的信息，按json格式返回数据'
    

    completion = client.chat.completions.create(
        model="gpt-4o-search-preview",
        web_search_options={},
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
    )

    print(completion.choices[0].message.content)
    return completion.choices[0].message.content

search_company("北京易控智驾澳大利亚分公司")
# Out:
# 根据您提供的格式，以下是关于“北京易控智驾澳大利亚分公司”的信息：
#
# ```json
# {
#     "客户": "北京易控智驾澳大利亚分公司",
#     "英文公司名": "Eacon Australia Pty Ltd",
#     "客户信息": "北京易控智驾科技有限公司（Eacon）是一家专注于矿山自动化运输解决方案的提供商。其澳大利亚分公司位于珀斯，致力于将先进的自动驾驶和电气化技术引入澳洲矿业市场。2023年底，易控智驾与澳洲最大的采矿承包商MACA签署了战略合作谅解备忘录，双方共同推进纯电动矿用车和混合动力矿用车在澳大利亚市场的应用，以及自动驾驶系统的落地。 ([eacon.com](https://www.eacon.com/news/268.html?utm_source=openai))",
#     "营收": "未公开",
#     "净利润": "未公开",
#     "人员规模": "未公开",
#     "联系人": "COO: 晋一宁博士",
#     "是否用友客户": "其他厂商",
#     "客户使用系统": "未公开",
#     "潜在商机": "易控智驾在澳洲市场的拓展，特别是与MACA的合作，可能带来对矿山自动化管理系统的需求。"
# }
# ```
#
#
# 请注意，部分信息如营收、净利润和人员规模未在公开资料中披露。此外，易控智驾的澳大利亚分公司地址为：Level 7, 191 St Georges Terrace, Perth WA 6000。 ([eacon.com](https://www.eacon.com/contact/?utm_source=openai))
# ...

# %%
import concurrent.futures
import json
import csv
import re
import time
from openai import OpenAI
from dotenv import load_dotenv

# 加载环境变量（例如 API key 等）
load_dotenv()

# 初始化 OpenAI 客户端
client = OpenAI()

# 公司列表
companies = [
    "中矿澳大利亚有限公司",
    "中国云铜（澳大利亚）投资开发有限公司",
    "国家电网公司驻澳大利亚办事处",
    "河北矿业（澳大利亚）控股有限责任公司",
    "云南锡业集团澳大利亚TDK资源有限公司",
    "沈阳远大铝业工程有限公司",
    "金风澳洲有限公司",
    "北京京能清洁能源电力股份有限公司（澳洲项目公司）",
    "中节能风电（澳大利亚）控股有限公司",
    "洛阳钼业澳洲公司",
    "阿林塔能源",
    "中远海运(澳洲)有限公司",
    "中车澳大利亚有限公司",
    "神华澳大利亚控股有限公司",
    "中石化国际事业澳大利亚有限公司",
    "天合光能",
    "澳中财富集团",
    "华光资源有限公司",
    "宙斯资源有限公司",
    "三一澳大利亚",
    "铭瑞锆业有限公司",
    "永刚集团",
    "澳洲五矿有限公司",
    "中信资源澳大利亚有限公司",
    "五矿资源有限公司",
    "中国电建澳大利亚发展有限公司",
    "神华清洁能源控股公司",
    "中远海运散运（澳洲）有限公司",
    "中车时代电气澳洲有限责任公司",
    "中联重科澳新公司",
    "澳大利亚中车长客轨道交通装备有限公司",
    "中车资阳（澳大利亚）有限公司",
    "Alinta Energy Pty Ltd",
    "三一澳大利亚有限公司",
    "五矿劲飞有限公司",
    "中石油技术开发公司澳大利亚子公司",
    "神火国际集团有限公司",
    "信发澳洲有限公司",
    "广东能源集团超康投资",
    "中海油",
    "中煤资源有限公司",
    "皖北煤电",
    "澳陕矿业",
    "中拓资源有限公司",
    "Huaxin Energy (Aust) Pty Ltd",
    "爱康能源澳大利亚有限公司",
    "PanAust Limited",
    "中国石油国际事业（澳大利亚）有限公司",
    "澳大利亚坤谦国际能源有限公司",
    "中石化国际事业澳大利亚公司",
    "中国华能澳洲代表处",
    "东方日升新能源（澳大利亚）有限公司",
    "中石油国际投资有限公司(澳大利亚）公司",
    "中国石化澳大利亚公司",
    "中石油工程建设公司",
    "金鑫设备有限责任公司",
    "中钢澳洲中西矿业有限公司",
    "宝钢澳大利亚矿业有限公司",
    "紫金矿业诺顿金田有限公司",
    "中海油澳大利亚国际控股有限公司",
    "中冶西澳矿业有限公司",
    "鞍钢澳大利亚投资有限公司",
    "宝钢澳大利亚有限公司",
    "宝武资源澳大利亚有限公司",
    "中国广东核电澳大利亚有限公司",
    "金川金田镍业有限公司",
    "马钢澳大利亚有限公司",
    "河北钢铁澳大利亚有限公司",
    "沙钢澳大利亚有限公司",
    "中钢澳大利亚矿业有限公司",
    "丰立澳大利亚有限公司",
    "中信泰富矿业管理有限公司",
    "济南高新控股集团明加尔金源有限公司",
    "中金岭南有色金属股份有限公司",
    "重钢澳大利亚有限公司",
    "宁夏天元锰业澳大利亚联合矿业有限公司",
    "山东黄金国际集团",
    "河南信阳钢铁澳大利亚公司",
    "金伯利铁矿有限公司",
    "科思米克资源控股有限公司",
    "中国国储能源澳大利亚有限公司",
    "广东东方锆业科技股份公司",
    "东方日升澳大利亚公司",
    "中石油国际投资（澳大利亚）公司西澳项目",
    "天齐锂业澳洲公司",
    "中远海运澳洲船务有限公司",
    "中国船级社澳大利亚办事处",
    "中国外运澳大利亚有限公司",
    "中石化润滑油有限公司",
    "凯瑞工程建设集团",
    "中车长江（澳大利亚）车辆服务有限公司",
    "湖南长沙黑金刚实业澳大利亚有限公司",
    "安徽三方新材料科技澳大利亚公司",
    "百年宝通澳大利亚通输送系统服务公司",
    "华特磁电澳大利亚公司",
    "青岛泰凯英轮胎澳大利亚有限公司",
    "南昌矿山机械澳大利亚公司",
    "江阴怡源设备安装有限公司",
    "三一集团澳大利亚公司",
    "中检集团澳大利亚公司",
    "大地(澳大利亚)工程有限公司",
    "广州普朗思电气科技有限公司",
    "疆宇科技有限公司",
    "天合光能股份有限公司",
    "阿里云",
    "中联重科澳新子公司",
    "北京易控智驾澳大利亚分公司",
]

def search_company(company_name):
    """
    调用 OpenAI 接口，根据给定的公司名称返回对应的文本内容
    """
    prompt = """
{
    "客户": "兖煤澳大利亚有限公司",
    "英文公司名": "YANCOAL AUSTRALIA LIMITED",
    "客户信息": "澳洲最大的煤炭出口商之一，生产优质的动力煤和焦煤。2004年由兖矿集团控股整合，现总部设于悉尼和纽卡斯尔附近的猎人谷。旗下主要矿区包括：36座煤矿，主要位于新南威尔士州中北部和昆士兰州，如: Eltanoballen、Mount Thorley Warkworth、Hunter Valley Operations等；客户目前通过新加坡子公司销售约62.26%，中国区占比约15.89。https://www.yancoal.com.au/",
    "营收": "68.6亿", 
    "净利润": "12.16亿",
    "人员规模": "3,000",
    "联系人": "CFO: 苏宁 (Kevin)\nhttps://www.linkedin.com/in/kevin-ning-su-fcpa-55397651/",
    "是否用友客户": "其他厂商", 
    "客户使用系统": "SAP",
    "潜在商机": ""
}
请参考上面的格式填写""" + '"' + company_name + '"的信息，按json格式返回数据'
    
    completion = client.chat.completions.create(
        model="gpt-4o-search-preview",
        web_search_options={},
        messages=[
            {"role": "user", "content": prompt},
        ],
    )
    
    return completion.choices[0].message.content

def query_company(company_name):
    """
    包装 search_company()，使用正则表达式匹配 ```json``` 包裹的内容，再解析 JSON 数据
    """
    try:
        result_str = search_company(company_name)
        # 使用正则表达式匹配 ```json``` 包裹的内容
        pattern = r"```json\s*(.*?)\s*```"
        match = re.search(pattern, result_str, re.DOTALL)
        if match:
            json_content = match.group(1)
        else:
            # 如果未匹配到，则尝试直接解析返回的内容
            json_content = result_str
        result_json = json.loads(json_content)
    except Exception as e:
        print(f"Error processing {company_name}: {e}")
        result_json = {"客户": company_name, "error": str(e)}
    return result_json

def main():
    results = []
    # 使用多线程执行查询，max_workers 可根据情况调整
    with concurrent.futures.ThreadPoolExecutor(max_workers=100) as executor:
        future_to_company = {executor.submit(query_company, comp): comp for comp in companies}
        for future in concurrent.futures.as_completed(future_to_company):
            comp = future_to_company[future]
            try:
                data = future.result()
                results.append(data)
                print(f"Finished processing: {comp}")
            except Exception as e:
                print(f"Error for {comp}: {e}")
            # 为避免请求过快可适当延时
            time.sleep(0.5)
    
    # 确定所有 JSON 数据中的所有键，用作 CSV 的表头
    all_keys = set()
    for entry in results:
        all_keys.update(entry.keys())
    all_keys = list(all_keys)

    # 写入 CSV 文件
    csv_filename = "company_data.csv"
    with open(csv_filename, "w", newline="", encoding="utf-8") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=all_keys)
        writer.writeheader()
        for row in results:
            writer.writerow(row)
    
    print(f"CSV 文件已保存到: {csv_filename}")

if __name__ == "__main__":
    main()
# Out:
# Finished processing: 中远海运(澳洲)有限公司
# Error processing 澳陕矿业: Expecting value: line 1 column 1 (char 0)
# Finished processing: 澳陕矿业
# Error processing 五矿劲飞有限公司: Expecting value: line 1 column 1 (char 0)
# Finished processing: 五矿劲飞有限公司
# Error processing 中海油澳大利亚国际控股有限公司: Expecting value: line 1 column 1 (char 0)Error processing 中国国储能源澳大利亚有限公司: Expecting value: line 1 column 1 (char 0)
#
# Finished processing: 国家电网公司驻澳大利亚办事处
# Error processing 河北矿业（澳大利亚）控股有限责任公司: Expecting value: line 1 column 1 (char 0)
# Error processing 中石油技术开发公司澳大利亚子公司: Expecting value: line 1 column 1 (char 0)
# Finished processing: 中矿澳大利亚有限公司
# Error processing 丰立澳大利亚有限公司: Expecting value: line 1 column 1 (char 0)
# Finished processing: 中国华能澳洲代表处
# Error processing 澳大利亚坤谦国际能源有限公司: Expecting value: line 1 column 1 (char 0)
# Error processing 中国广东核电澳大利亚有限公司: Expecting value: line 1 column 1 (char 0)
# Error processing 中国船级社澳大利亚办事处: Expecting value: line 1 column 1 (char 0)
# ...

# %%
result_str = search_company("澳陕矿业")

# %%
result_str
# Out:
# '很抱歉，目前无法找到关于“澳陕矿业”的详细信息。可能是由于该公司规模较小或信息未公开。如果您能提供更多细节，如公司的英文名称、所在行业或其他相关信息，我将尽力为您查找并提供所需的资料。 '
